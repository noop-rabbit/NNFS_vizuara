# %% [markdown]
# https://www.youtube.com/watch?v=qFMpq46hEjE&list=PLPTV0NXA_ZSj6tNyn_UadmUeU3Q3oR-hu&index=4

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.2

# %%
#!pip install nnfs
#!pip install matplotlib

# %%
#!pip install nnfs
from nnfs.datasets import spiral_data
import numpy as np
import nnfs
nnfs.init()
import matplotlib.pyplot as plt
X, y = spiral_data(samples=100, classes=3)
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
plt.scatter(X[:,1], X[:,0], c=y, cmap='brg')
plt.show()

# %% [markdown]
# ![image.png](attachment:55241c2d-52fc-48bd-b5d8-f2e65bab807b.png)
# ![image.png](attachment:2e70ce78-b532-451e-82c7-979fc4091399.png)
# ![image.png](attachment:e7c34bdc-2ee4-485a-9ece-917886037bec.png)

# %%
import numpy as np
import nnfs 
from nnfs.datasets import spiral_data
nnfs.init()

#Dense layer
class Layer_Dense:
    #layer init
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons) #not n_neurons x n_inputs --> 
        self.biases = np.zeros((1, n_neurons))                     #to avoid the transpose in dot products

    #forward pass
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases
        return self.output

#Create dataset
X, y = spiral_data(samples=100, classes=3)
#X = np.random.randn(300, 10)
dense1 = Layer_Dense(2, 3)
dense1.forward(X)
print(dense1.output[:5])

dense2 = Layer_Dense(3, 5)
dense2.forward(dense1.forward(X))
#print(dense2.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.0475188e-04  1.1395361e-04 -4.7983500e-05]
#  [-2.7414842e-04  3.1729150e-04 -8.6921798e-05]
#  [-4.2188365e-04  5.2666257e-04 -5.5912682e-05]
#  [-5.7707680e-04  7.1401405e-04 -8.9430439e-05]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 24
#      22 print(dense1.output[:5])
#      23 dense2 = Layer_Dense(3, 5)
# ---> 24 dense2.forward(dense1.forward(X))
#      25 #print(dense2.output[:5])
#
# Cell In[10], line 15, in Layer_Dense.forward(self, inputs)
#      14 def forward(self, inputs):
# ---> 15     self.output = np.dot(inputs, self.weights) + self.biases
#
# File ~/anaconda3/envs/NNFS/lib/python3.14/site-packages/nnfs/core.py:22, in init.<locals>.dot(*args, **kwargs)
#      21 def dot(*args, **kwargs):
# ---> 22     return orig_dot(*[a.astype('float64') for a in args], **kwargs).astype('float32')
# ...

# %%
print(X.shape)
# Out:
# (200, 2)
